# %% [markdown]
# #### Tool Usage
#
# - Press Enter to accept the whole suggestion.
# - Press Ctrl + Alt + → to accept suggestions one word at a time.
# - Press Tab to force trigger auto-completion.

# %% [markdown]
# We will demonstrate the usage of this tool by simple tasks regarding residential demolitions. The dataset can be referred to [this website](https://github.com/statesman/demolitions/blob/master/data-processed/Demo%20residential.csv) Please run the code cell below first and then follow the instructions of Examle 1, 2, and 3.

# %%
import pandas as pd
demo = pd.read_csv("https://raw.githubusercontent.com/statesman/demolitions/master/data-processed/Demo%20residential.csv")
demo["TotalExistingBldgSQFT"] = demo["TotalExistingBldgSQFT"].str.replace(",","").astype(float)

# %% [markdown]
# ##### Example 1
#
# - Write a line of code which fills NA value of Project ID with 0, like: `demo["ProjectID"] = demo["ProjectID"].fillna(0)`
# - Try to use **Enter** or **Ctrl + Alt + →** to accept the suggestion when you are typing.
# - You can observe the changes on the side panel while you are typing.

# %% [markdown]
# ##### Example 2
#
# - Please write a line of code which calculate total existing building square footage for each status, like: `demo2 = demo.groupby("StatusCurrent")["TotalExistingBldgSQFT"].sum()`
# - Same as above, you can observe the changes on the side panel while you are typing.
# - After running the code, you can inspect the result through the side panel.

# %% [markdown]
# ##### Example 3
#
# - Sort the demo table by "StatusCurrent" in descending order.
# - Use Tab to trigger auto-completion for the partial code below.

# %%
# Sort the demo table by "StatusCurrent" in descending order.
demo = demo.sort_values(

# %% [markdown]
# If you still feel unfamiliar with using this tool, you can try some more examples to get a better feel for it. Like:
# - Filter the table demo where the "TotalExistingBldgSQFT" is greater than 1000.
# - Select the columns "StatusCurrent" and "TotalExistingBldgSQFT" from the table demo.
# - Replace the substring "," with "" in the column "TotalJobValuation" of the table demo.
